# %% [markdown]
# <a href="https://colab.research.google.com/github/NadineAppiah/lab-4-llm-decision-support/blob/main/lab4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#part 0
import os
from google.colab import userdata
from openai import OpenAI

API_KEY = userdata.get('GROQ_API_KEY')
if not API_KEY:
  raise ValueError("GROQ_API_KEY not found in environment variables")
print('API key loaded successfully.')

client = OpenAI(
    api_key=API_KEY,
    base_url="https://api.groq.com/openai/v1"
)

MODEL = "llama-3.3-70b-versatile"
print("client ready")
# Out:
# API key loaded successfully.
# client ready

# %%
#part 1.1
def ask_llm(user_prompt, system_prompt = "You are a helpful assistant.",
  temperature = 0.7, max_tokens = 500):
  response = client.chat.completions.create(
    model=MODEL,
    messages=[
      {"role": "system", "content": system_prompt},
      {"role": "user", "content": user_prompt}
    ],
    temperature=temperature,
    max_tokens=max_tokens
  )
  return response

response = ask_llm("What is artificial intelligence?")
print(response.choices[0].message.content)

print("\nUsage:")
print(response.usage)
# Out:
# Artificial intelligence (AI) refers to the development of computer systems that can perform tasks that would typically require human intelligence, such as:
#
# 1. **Learning**: AI systems can learn from data and improve their performance over time.
# 2. **Problem-solving**: AI systems can analyze problems and find solutions using algorithms and logical reasoning.
# 3. **Decision-making**: AI systems can make decisions based on data and rules.
# 4. **Perception**: AI systems can interpret and understand data from sensors, such as images, speech, and text.
# 5. **Natural Language Processing (NLP)**: AI systems can understand and generate human-like language.
#
# The goal of AI is to create systems that can think and act like humans, but with the ability to process and analyze vast amounts of data much faster and more accurately.
#
# There are several types of AI, including:
#
# 1. **Narrow or Weak AI**: Designed to perform a specific task, such as facial recognition or language translation.
# 2. **General or Strong AI**: A hypothetical AI system that possesses human-like intelligence and can perform any intellectual task.
# 3. **Superintelligence**: An AI system that is significantly more intelligent than the best human minds.
#
# AI has many applications, including:
#
# 1. **Virtual assistants**: Siri, Alexa, and Google Assistant
# 2. **Image recognition**: Self-driving cars, facial recognition systems
# 3. **Natural Language Processing**: Chatbots, language translation software
# 4. **Predictive analytics**: Forecasting sales, predicting customer behavior
# 5. **Robotics**: Industrial robots, autonomous vehicles
#
# The development of AI has the potential to revolutionize many industries and aspects of our lives, but it also raises important questions about ethics, safety, and the future of work.
#
# Usage:
# CompletionUsage(completion_tokens=351, prompt_tokens=46, total_tokens=397, completion_tokens_details=None, prompt_tokens_details=None, queue_time=0.063926439, prompt_time=0.004653621, completion_time=0.695446751, total_time=0.700100372)

# %% [markdown]
# **Anatomy of a call**
# 1. The system role provides instructions that define the LLM's behavior, purpose, or style, while the user role contains the specific request or question from the user. For example, a system message could tell the model to act as a financial decision-support assistant, while the user message could ask it to evaluate a customer's loan application.
#
# 2. A token is a small unit of text that an LLM processes. Words, parts of words, and punctuation can each form tokens. API providers charge based on tokens because longer inputs and outputs require more computational resources than shorter ones, so token usage is a better measure of the work performed than simply counting requests.

# %%
#part 1.2
question = "Suggest a name for a savings product for market traders in Accra."

print("====TEMPERATURE 0.0====")

for i in range(5):
  response = ask_llm(question, temperature=0.0, max_tokens=100)
  print(f"Response {i + 1}:")
  print(response.choices[0].message.content)

print("====TEMPERATURE 1.2====")

for i in range(5):
  response = ask_llm(question, temperature=1.2, max_tokens=100)
  print(f"Response {i + 1}:")
  print(response.choices[0].message.content)
# Out:
# ====TEMPERATURE 0.0====
# Response 1:
# Here are a few suggestions for a savings product for market traders in Accra:
#
# 1. **Makola Save**: "Makola" is a well-known market in Accra, so this name could resonate with market traders.
# 2. **Trader's Treasure**: This name emphasizes the idea of saving and accumulating wealth.
# 3. **Sika Kokoo**: "Sika" means "money" in the Akan language, and "Kokoo" means "gather" or "collect
# Response 2:
# Here are a few suggestions for a savings product for market traders in Accra:
#
# 1. **Makola Save**: "Makola" is a well-known market in Accra, so this name could resonate with market traders.
# 2. **Trader's Treasure**: This name emphasizes the idea of saving and accumulating wealth.
# 3. **Accra Amanfu**: "Amanfu" is a Ghanaian word for "savings" or "treasury", which could add a local touch
# Response 3:
# Here are a few suggestions for a savings product for market traders in Accra:
#
# 1. **Makola Save**: "Makola" is a well-known market in Accra, so this name could resonate with market traders.
# 2. **Trader's Treasure**: This name emphasizes the idea of saving and accumulating wealth.
# 3. **Accra Amanfu**: "Amanfu" is a Ghanaian word for "savings" or "treasury", so this name incorporates local language
# Response 4:
# Here are a few suggestions for a savings product for market traders in Accra:
#
# 1. **Makola Save**: "Makola" is a well-known market in Accra, so this name could resonate with market traders.
# 2. **Trader's Treasure**: This name emphasizes the idea of saving and accumulating wealth.
# 3. **Accra Amanfu**: "Amanfu" is a Ghanaian word for "savings" or "treasury", so this name incorporates local language
# Response 5:
# Here are a few suggestions for a savings product for market traders in Accra:
#
# 1. **Makola Save**: "Makola" is a well-known market in Accra, so this name could resonate with market traders.
# 2. **Trader's Treasure**: This name emphasizes the idea of saving and accumulating wealth, which is a key goal for market traders.
# 3. **Sika Saver**: "Sika" is the Ghanaian word for "money", so this name incorporates a
# ====TEMPERATURE 1.2====
# Response 1:
# Here are some name suggestions for a savings product for market traders in Accra:
#
# 1. **Makola Save**: "Makola" is a well-known market in Accra, so this name will resonate with traders.
# 2. **TradeBoost**: This name suggests that the savings product will help traders boost their businesses.
# 3. **MarketMali**: "Mali" means "money" in the Ga language, which is spoken in Accra. This name is catchy and easy to
# Response 2:
# Here are some name suggestions for a savings product tailored to market traders in Accra:
#
# 1. **Makola Save**: "Makola" is a well-known market in Accra, so this name immediately resonates with market traders.
# 2. **Traders' Treasure**: This name emphasizes the idea of saving and accumulating wealth, which is a treasure for traders.
# 3. **Asempa Savings**: "Asempa" is a Ghanaian word meaning "good news"
# Response 3:
# Considering the cultural and economic context of Accra, here are a few suggestions for a savings product name tailored to market traders:
#
# 1. **Makola Savings**: "Makola" is a well-known market in Accra, so this name would resonate with traders and evoke a sense of familiarity.
# 2. **Sika Kokoo**: "Sika" means "money" in the Akan language, and "Kokoo" means "gather" or "collect." This name could
# Response 4:
# For a savings product targeting market traders in Accra, here are a few suggestions:
#
# 1. **Makola Maxi Save**: "Makola" is a reference to one of the largest markets in Accra, and "Maxi Save" conveys the idea of maximizing savings.
# 2. **TradaSave**: A combination of "trade" and "save," this name emphasizes the product's focus on market traders.
# 3. **MarketMaestro**: This name positions the savings product
# Response 5:
# Here are a few suggestions for a savings product for market traders in Accra:
#
# 1. **Makola Savings**: "Makola" is a well-known market in Accra, so this name could resonate with traders.
# 2. **Trader's Treasure**: This name plays on the idea of savings being a valuable treasure for market traders.
# 3. **Abossey Okai Account**: "Abossey Okai" is another major market in Accra, so this name could be appealing

# %% [markdown]
# **Temperature**
# 1. At temperature 0.0, the responses were generally more consistent and similar to one another. At temperature 1.2, the responses showed greater variation and creativity. For a loan decision-support system, a low temperature such as 0.0-0.3 would be more appropriate because the system should produce consistent and predictable responses rather than highly random recommendations. The final loan decision should also be based on defined financial criteria rather than creativity.

# %%
#part 2
LETTERS = {
"L001": """Dear Sir/Madam,
My name is Akosua Mensah and I have been selling provisions at Makola Market for 12 years.
I am applying for a loan of GHS 8,000 to buy a deep freezer and expand into frozen foods.
My current stall makes about GHS 900 profit each month. I have saved GHS 2,500 with your
susu scheme over the past two years and I have never missed a contribution. I can repay
GHS 450 monthly over 20 months. My sister, a teacher, will stand as my guarantor.
Thank you for considering my application.""",

"L002": """Hello,
I am Kwame Boateng, a commercial driver in Kumasi. I need GHS 25,000 urgently to repair my
trotro engine and settle some personal debts. Business has been slow but it will surely
pick up after the festive season. I can pay back whenever the money comes. I do not have
collateral at the moment but God willing everything will be fine. Please help me quickly.""",

"L003": """Dear Loan Committee,
I am Efua Darko, owner of Darko Fashions, a registered dressmaking business in Takoradi
(registration no. BN-2019-4482). I employ three apprentices. I request GHS 15,000 to
purchase two industrial sewing machines and fabric stock ahead of the Christmas season.
Last year my December revenue alone was GHS 22,000; monthly profit averages GHS 2,800.
I hold a fixed deposit of GHS 5,000 with GCB which I can pledge. Proposed repayment:
GHS 1,100 monthly for 15 months. Attached are my sales records for the past 18 months.""",

"L004": """Good day,
My name is Yaw Owusu. I want a loan for my poultry farm at Nsawam. The amount is GHS 12,000
for feed and 500 new layers. I started the farm last year. Sometimes I make good money,
around GHS 1,500 in a good month, but bird flu affected us in March and I lost many birds.
I am rebuilding now. I can repay in 18 months. My uncle has agreed to guarantee the loan
with his taxi.""",

"L005": """Dear Manager,
I am writing on behalf of the Adenta Women's Weaving Cooperative (14 members). We seek
GHS 30,000 to buy a bulk order of yarn directly from the factory, cutting out middlemen and
raising our margins from 15% to about 35%. The cooperative has operated for 6 years and
holds GHS 9,000 in our group account. We propose repayment of GHS 2,000 monthly over
16 months, backed by our group savings and joint liability agreement.""",

"L006": """Hi,
This is Kofi. I saw your advert. I want GHS 50,000 to start a car washing business, a
provision shop, and also import phones from Dubai. I am 22 and full of energy. I have not
started any of these yet but my friends say I am very business minded. I will pay back in
one year when the businesses are booming. No collateral but I am trustworthy.""",
}

GOLD = {
  "L001": {"applicant_name": "Akosua Mensah", "amount_ghs": 8000,  "purpose": "buy deep freezer / expand into frozen foods",
           "monthly_profit_ghs": 900,  "has_collateral_or_guarantor": True,  "repayment_months": 20},
  "L003": {"applicant_name": "Efua Darko",    "amount_ghs": 15000, "purpose": "industrial sewing machines and fabric stock",
           "monthly_profit_ghs": 2800, "has_collateral_or_guarantor": True,  "repayment_months": 15},
  "L006": {"applicant_name": "Kofi",          "amount_ghs": 50000, "purpose": "car wash, provision shop, phone imports",
           "monthly_profit_ghs": None, "has_collateral_or_guarantor": False, "repayment_months": 12},
}

print(f"{len(LETTERS)} letters loaded.")
# Out:
# 6 letters loaded.

# %%
#part 3.1
SUMMARY_PROMPT_V1 = "Summarize this:"

for letter_id in ['L002', 'L006']:
  response = ask_llm(f"{SUMMARY_PROMPT_V1} {LETTERS[letter_id]}",
                     temperature = 0.7, max_tokens = 200)
  print(f"Letter {letter_id}:")
  print(response.choices[0].message.content)

SUMMARY_SYSTEM_PROMPT_V2 = """
You are an assistant to a microfinance loan officer.
Summarise loan applications into a brief summary that a busy loan officer can quickly scan.

Requirements:
-Write 3-4 sentences.
-Be factual and neutral.
-Include applicants business and loan purpose.
-Include repayment plan.
-Include collateral, guarantor, savings, and important financial information.
-Do not invent, assume, or infer information that is not stated in the letter.
-Do not make approval or rejection decisions on behalf of the loan officer.
"""

SUMMARY_PROMPT_V2 = "Summarize this letter into a brief summary:"

for letter_id in ['L002', 'L006']:
  user_prompt = f"{SUMMARY_PROMPT_V2} {LETTERS[letter_id]}"

  response = ask_llm(user_prompt,system_prompt = SUMMARY_SYSTEM_PROMPT_V2,
                     temperature = 0, max_tokens=200)
  print("\n---V1---")
  print(f"Letter {letter_id}:")
  print(response.choices[0].message.content)

for letter_id in ["L002", "L006"]:
  response_v1 = ask_llm(f"{SUMMARY_PROMPT_V1} {LETTERS[letter_id]}",
                      temperature = 0.7, max_tokens=200)
  print(f"Letter {letter_id}:")
  print(response_v1.choices[0].message.content)

  response_v2 = ask_llm(f"{SUMMARY_PROMPT_V2} {LETTERS[letter_id]}",
                      temperature = 0, max_tokens=200)
  print("\n---V2---")
  print(f"Letter {letter_id}:")
  print(response_v2.choices[0].message.content)
# Out:
# Letter L002:
# Kwame Boateng, a commercial driver in Kumasi, is requesting GHS 25,000 to repair his vehicle's engine and pay off personal debts. He's experiencing a slow period in business but expects it to improve after the festive season. He has no collateral to offer but promises to repay the loan as soon as possible.
# Letter L006:
# Kofi, a 22-year-old, is requesting GHS 50,000 to start three businesses: a car washing service, a provision shop, and a phone import business from Dubai. He has no prior experience, but claims to be "business-minded" based on his friends' opinions. He promises to repay the loan within a year, once his businesses are successful, but is unable to offer any collateral, relying on his personal guarantee of being trustworthy.
#
# ---V1---
# Letter L002:
# Kwame Boateng, a commercial driver, is applying for a GHS 25,000 loan to repair his trotro engine and settle personal debts. He intends to repay the loan from his business income, expecting an increase in earnings after the festive season. He does not have collateral to offer at present. The applicant has not specified a clear repayment plan, but is seeking urgent disbursement of the loan.
#
# ---V1---
# Letter L006:
# Kofi, a 22-year-old, is applying for a GHS 50,000 loan to start a car washing business, a provision shop, and a phone import business. The loan will be repaid in one year, once the businesses are established. Kofi does not have collateral to offer, but claims to be trustworthy. He has no existing savings or financial track record mentioned, and no guarantor is provided.
# Letter L002:
# Kwame Boateng, a commercial driver in Kumasi, is urgently seeking GHS 25,000 to repair his vehicle's engine and pay off personal debts. He's experiencing a slow business period but expects it to improve after the festive season. He has no collateral to offer but promises to pay back the loan as soon as possible.
#
# ---V2---
# Letter L002:
# Kwame Boateng, a commercial driver, is requesting GHS 25,000 to repair his vehicle's engine and settle debts, promising to repay when business improves after the festive season.
# Letter L006:
# Kofi, a 22-year-old, is seeking a loan of GHS 50,000 to start three businesses: a car washing service, a provision shop, and a phone import business from Dubai. Although he has no prior experience and no collateral, he claims to be "business-minded" and promises to repay the loan within a year when his businesses are successful, relying on his personal trustworthiness as assurance.
#
# ---V2---
# Letter L006:
# Kofi, a 22-year-old, is seeking GHS 50,000 to start three businesses: a car washing service, a provision shop, and a phone import business. He claims to be business-minded and promises to repay the loan within a year, without offering any collateral, relying on his personal trustworthiness.

# %% [markdown]
# **Summarisation prompt**
# 1. V1 produced a general summary but did not explicitly instruct the model to focus on information important to a loan officer. V2 was more focused because it required the summary to include the applicant's business, loan purpose, financial information, repayment information, and collateral or guarantor information. V2 was also more consistent in length because it explicitly required 3-4 sentences and instructed the model to remain factual and neutral.
# 2. "No invented details" is essential because the system must base its output only on information actually provided by the applicant. Inventing financial information, collateral, income, or other facts could mislead the loan officer and affect an important financial decision. This type of failure is commonly called an LLM hallucination.

# %%
#part 3.2
import json
import pandas as pd

EXTRACT_PROMPT = """
You are a data extraction assistant for a microfinance institution.

Extract information from the loan application letter and return only
a valid JSON object.

The JSON object must contain EXACTLY these keys:
{
    "applicant_name": "string",
    "amount_ghs": number,
    "purpose": "string",
    "monthly_profit_ghs": number or null,
    "has_collateral_or_guarantor": boolean,
    "repayment_months": number or null}

Rules:
1. Extract information only from the letter.
2. If a field is not stated in the letter, use null.
3. Do not invent, assume, or infer information.
4. amount_ghs must be a number, not a string.
5. monthly_profit_ghs must be a number or null.
6. has_collateral_or_guarantor must be true or false.
7. repayment_months must be a number or null.
8. Return ONLY the JSON object.
9. Do not include explanations or introductions.
10. Do not use Markdown code fences.
11. The first character of your response must be { and the last
    character must be }.

Worked example:
Loan Application Letter:
"Dear Manager,
My name is Ama Addo. I run a small fruit stall in Accra.
I am requesting GHS 6,000 to purchase a refrigerator and more stock.
My average monthly profit is GHS 700. My brother will guarantee the loan.
I will repay the loan over 12 months."

Correct JSON:
{
    "applicant_name": "Ama Addo",
    "amount_ghs": 6000,
    "purpose": "refrigerator and more stock",
    "monthly_profit_ghs": 700,
    "has_collateral_or_guarantor": true,
    "repayment_months": 12}
"""

EXTRACT_USER_PROMPT = """
Extract the required fields from this loan application:
{letter_text}
"""

def extract_fields(letter_text, temperature = 0):
    response = ask_llm(
        EXTRACT_USER_PROMPT.format(letter_text=letter_text),
        system_prompt=EXTRACT_PROMPT,
        temperature=temperature,
        max_tokens=300
    )

    result = response.choices[0].message.content.strip()

    if result.startswith("```json"):
        result = result[7:]

    if result.startswith("```"):
        result = result[3:]

    if result.endswith("```"):
        result = result[:-3]

    result = result.strip()

    start = result.find("{")
    end = result.rfind("}")

    if start != -1 and end != -1:
        result = result[start:end + 1]

    try:
        return json.loads(result)

    except json.JSONDecodeError:
        print(f"Error decoding JSON: {result}")
        return None

results = []

for letter_id, letter_text in LETTERS.items():
    extracted = extract_fields(letter_text)
    if extracted is not None:
        extracted["letter_id"] = letter_id
        results.append(extracted)

df = pd.DataFrame(results)
df
# Out:
#                        applicant_name  amount_ghs  \
# 0                       Akosua Mensah        8000
# 1                       Kwame Boateng       25000
# 2                          Efua Darko       15000
# 3                           Yaw Owusu       12000
# 4  Adenta Women's Weaving Cooperative       30000
# 5                                Kofi       50000
#
#                                              purpose  monthly_profit_ghs  \
# 0    buy a deep freezer and expand into frozen foods               900.0
# 1  repair my trotro engine and settle some person...                 NaN
# 2  purchase two industrial sewing machines and fa...              2800.0
# 3                            feed and 500 new layers              1500.0
# 4                           buy a bulk order of yarn                 NaN
# 5  start a car washing business, a provision shop...                 NaN
#
#    has_collateral_or_guarantor  repayment_months letter_id
# 0                         True              20.0      L001
# 1                        False               NaN      L002
# 2                         True              15.0      L003
# 3                         True              18.0      L004
# 4                         True              16.0      L005
# 5                        False              12.0      L006

# %% [markdown]
# **Structured extraction**
# 1. The few-shot example should not come from the six letters because using one of the evaluation letters could make the prompt specifically tailored to that data. This could give the model information about the expected answers and make the evaluation less representative of how well the extraction system generalizes to unseen applications.
# 2. "Use null, do not guess" prevents the model from filling missing information with assumptions. Without this instruction, an LLM may generate plausible-looking values that were never provided in the letter. This is especially problematic in loan applications because invented financial information could mislead the loan officer.
# 3. Temperature 0 is appropriate for extraction because we want consistent and predictable outputs rather than creative variations. The task is to accurately extract information that already exists in the letter, not to generate new content. Higher temperatures are more appropriate for tasks where creativity and variety are desired.

# %%
#part 3.3
BRIEF_PROMPT = """
You are an assistant supporting a microfinance loan officer.

Your role is to organize information and highlight factors that a human
loan officer should consider. You must NOT make the final loan decision.

Using the loan application letter and the extracted information, produce
a concise decision-support brief with exactly these four sections:

1. Strengths
- List positive factors that are explicitly supported by the letter.
- Use bullet points.

2. Risks / Red Flags
- List potential concerns or risks supported by the letter.
- Use bullet points.
- Do not invent risks that are not supported by the information provided.

3. Missing Information
- List important information or documents that the loan officer should
  request before making a decision.
- Use bullet points.

4. Suggested Next Step
- Suggest an appropriate action for the loan officer, such as:
  "request documents", "invite for interview", or "flag for senior review".
- Do NOT say "approve" or "reject".

Important:
- Base the brief only on the information provided.
- Do not invent facts.
- Do not make assumptions about the applicant.
- The final lending decision must be made by a human loan officer.
- Keep the brief concise and professional.

"""

def generate_brief(letter_text, extracted):
    user_prompt = f"""
    Loan Application Letter:
    {letter_text}

    Extracted Information:
    {json.dumps(extracted, indent=2)}
    """

    response = ask_llm(
        user_prompt,
        system_prompt=BRIEF_PROMPT,
        temperature=0,
        max_tokens=300
    )

    return response.choices[0].message.content

briefs = {}
for letter_id, letter_text in LETTERS.items():
    extracted = extract_fields(letter_text)
    if extracted is not None:
      brief = generate_brief(letter_text, extracted)
      briefs[letter_id] = brief

for letter_id in ["L001","L002", "L006"]:
  print(f"Letter {letter_id}:")
  print(briefs[letter_id])
# Out:
# Letter L001:
# ## 1. Strengths
# * The applicant has 12 years of experience selling provisions at Makola Market.
# * The applicant has a stable monthly profit of GHS 900.
# * The applicant has saved GHS 2,500 with the susu scheme over two years without missing a contribution.
# * The applicant has a guarantor, her sister, who is a teacher.
# * The applicant has a clear repayment plan of GHS 450 monthly over 20 months.
#
# ## 2. Risks / Red Flags
# * The applicant is requesting a loan that is significantly larger than her monthly profit, which may pose a repayment risk.
# * The expansion into frozen foods may come with additional operational risks and costs.
#
# ## 3. Missing Information
# * Detailed business plan and market analysis for the expansion into frozen foods.
# * Information about the applicant's sister, the guarantor, such as her income and employment stability.
# * Collateral or asset information to secure the loan.
# * Credit history and other debt obligations of the applicant.
#
# ## 4. Suggested Next Step
# Request additional documents and information, including a detailed business plan, guarantor's employment and income verification, and collateral or asset information, to further assess the loan application.
# Letter L002:
# **Decision-Support Brief**
#
# 1. **Strengths**
# * The applicant has a clear purpose for the loan, which is to repair his trotro engine and settle personal debts.
# * The applicant is expecting an increase in business after the festive season, which could potentially improve his repayment ability.
#
# 2. **Risks / Red Flags**
# * The applicant's business has been slow, which may impact his ability to repay the loan.
# * The applicant does not have collateral or a guarantor, which increases the risk of the loan.
# * The applicant does not have a clear repayment plan, stating he can pay back "whenever the money comes".
#
# 3. **Missing Information**
# * Monthly profit or income statement to assess the applicant's repayment ability.
# * Detailed breakdown of the expenses for repairing the trotro engine.
# * Information on the applicant's personal debts and their impact on his financial situation.
# * Repayment plan or proposed repayment schedule.
#
# 4. **Suggested Next Step**
# Request additional financial information and a detailed repayment plan from the applicant to further assess his creditworthiness and ability to repay the loan.
# Letter L006:
# ## 1. Strengths
# * The applicant, Kofi, is young and full of energy, which could be beneficial for starting and managing new businesses.
# * Kofi has multiple business ideas, indicating potential for diversification and risk management.
# * The applicant is confident in their business abilities, as supported by their friends' opinions.
#
# ## 2. Risks / Red Flags
# * The applicant has no prior experience in starting or running a business.
# * There is no collateral or guarantor to secure the loan.
# * The repayment plan relies on the businesses booming within a year, which is uncertain.
# * The applicant lacks a proven track record of business success.
#
# ## 3. Missing Information
# * Detailed business plans for the car washing business, provision shop, and phone import business.
# * Projected monthly profits for each business venture.
# * Information on the applicant's education, skills, and experience relevant to the proposed businesses.
# * Market research and analysis to support the viability of the businesses.
#
# ## 4. Suggested Next Step
# Request additional documents and information, including business plans, financial projections, and market research, to further assess the applicant's creditworthiness and the viability of the proposed businesses.

# %% [markdown]
# **Decision support brief**
# 1. The brief for L003 identified several strengths, including an established registered business, three apprentices, a stated monthly profit of GHS 2,800, a fixed deposit that can be pledged, and a specific repayment plan. It also identified useful documents such as the sales records that should be reviewed. In contrast, L006 had significant red flags because the proposed businesses have not yet started, no monthly profit is provided, there is no collateral or guarantor, and the repayment plan depends on the businesses becoming successful. The system therefore identified substantially stronger evidence for L003 than for L006.
# 2. Practically, the model can misunderstand information or overlook important factors, so a qualified loan officer must verify the evidence and apply the institution's lending criteria. Ethically, automated lending decisions can affect people's access to financial services and may introduce unfair or biased outcomes. Therefore, the LLM should identify strengths, risks, and missing information while leaving the final decision to a human.
