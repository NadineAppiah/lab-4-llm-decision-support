# %% [markdown]
# <a href="https://colab.research.google.com/github/NadineAppiah/lab-4-llm-decision-support/blob/main/lab4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#part 0
import os
from google.colab import userdata
from openai import OpenAI

API_KEY = userdata.get('GROQ_API_KEY')
if not API_KEY:
  raise ValueError("GROQ_API_KEY not found in environment variables")
print('API key loaded successfully.')

client = OpenAI(
    api_key=API_KEY,
    base_url="https://api.groq.com/openai/v1"
)

MODEL = "llama-3.3-70b-versatile"
print("client ready")
# Out:
# API key loaded successfully.
# client ready

# %%
#part 1.1
def ask_llm(user_prompt, system_prompt = "You are a helpful assistant.",
  temperature = 0.7, max_tokens = 500):
  response = client.chat.completions.create(
    model=MODEL,
    messages=[
      {"role": "system", "content": system_prompt},
      {"role": "user", "content": user_prompt}
    ],
    temperature=temperature,
    max_tokens=max_tokens
  )
  return response

response = ask_llm("What is artificial intelligence?")
print(response.choices[0].message.content)

print("\nUsage:")
print(response.usage)
# Out:
# Artificial intelligence (AI) refers to the development of computer systems that can perform tasks that would typically require human intelligence, such as:
#
# 1. **Learning**: AI systems can learn from data and improve their performance over time.
# 2. **Problem-solving**: AI systems can analyze situations, identify patterns, and make decisions.
# 3. **Reasoning**: AI systems can draw inferences, make predictions, and understand natural language.
# 4. **Perception**: AI systems can interpret and understand data from sensors, such as images, speech, and text.
#
# The goal of AI is to create systems that can think and act like humans, but with the ability to process and analyze vast amounts of data much faster and more accurately.
#
# There are several types of AI, including:
#
# 1. **Narrow or Weak AI**: Designed to perform a specific task, such as facial recognition, language translation, or playing chess.
# 2. **General or Strong AI**: A hypothetical AI system that possesses human-like intelligence and can perform any intellectual task.
# 3. **Superintelligence**: An AI system that is significantly more intelligent than the best human minds.
#
# AI has many applications, including:
#
# 1. **Virtual assistants**: Like Siri, Alexa, or Google Assistant.
# 2. **Image and speech recognition**: Used in self-driving cars, security systems, and voice-controlled devices.
# 3. **Natural Language Processing (NLP)**: Used in chatbots, language translation software, and text analysis tools.
# 4. **Predictive analytics**: Used in finance, healthcare, and marketing to analyze data and make predictions.
#
# AI has the potential to revolutionize many industries and aspects of our lives, but it also raises important questions about ethics, bias, and the future of work.
#
# Do you have any specific questions about AI or its applications?
#
# Usage:
# CompletionUsage(completion_tokens=361, prompt_tokens=46, total_tokens=407, completion_tokens_details=None, prompt_tokens_details=None, queue_time=0.063868974, prompt_time=0.001447196, completion_time=0.704018636, total_time=0.705465832)

# %% [markdown]
# **Anatomy of a call**
# 1. The system role provides instructions that define the LLM's behavior, purpose, or style, while the user role contains the specific request or question from the user. For example, a system message could tell the model to act as a financial decision-support assistant, while the user message could ask it to evaluate a customer's loan application.
#
# 2. A token is a small unit of text that an LLM processes. Words, parts of words, and punctuation can each form tokens. API providers charge based on tokens because longer inputs and outputs require more computational resources than shorter ones, so token usage is a better measure of the work performed than simply counting requests.

# %%
#part 1.2
question = "Suggest a name for a savings product for market traders in Accra."

print("====TEMPERATURE 0.0====")

for i in range(5):
  response = ask_llm(question, temperature=0.0, max_tokens=100)
  print(f"Response {i + 1}:")
  print(response.choices[0].message.content)

print("====TEMPERATURE 1.2====")

for i in range(5):
  response = ask_llm(question, temperature=1.2, max_tokens=100)
  print(f"Response {i + 1}:")
  print(response.choices[0].message.content)
# Out:
# ====TEMPERATURE 0.0====
# Response 1:
# Here are a few suggestions for a savings product for market traders in Accra:
#
# 1. **Makola Save**: "Makola" is a well-known market in Accra, so this name could resonate with market traders.
# 2. **Trader's Treasure**: This name emphasizes the idea of saving and accumulating wealth.
# 3. **Accra Amanfu**: "Amanfu" is a Ghanaian word for "savings" or "treasury", so this name incorporates local language
# Response 2:
# Here are a few suggestions for a savings product for market traders in Accra:
#
# 1. **Makola Save**: "Makola" is a well-known market in Accra, so this name could resonate with market traders.
# 2. **Trader's Treasure**: This name emphasizes the idea of saving and accumulating wealth, which could appeal to market traders.
# 3. **Sika Souce**: "Sika" means "money" in the Akan language, which is widely spoken in Ghana
# Response 3:
# Here are a few suggestions for a savings product for market traders in Accra:
#
# 1. **Makola Save**: "Makola" is a well-known market in Accra, so this name could resonate with market traders.
# 2. **Trader's Treasure**: This name emphasizes the idea of saving and accumulating wealth, which could appeal to market traders.
# 3. **Sika Souce**: "Sika" means "money" in the Akan language, which is widely spoken in Ghana
# Response 4:
# Here are a few suggestions for a savings product for market traders in Accra:
#
# 1. **Makola Save**: "Makola" is a well-known market in Accra, so this name could resonate with market traders.
# 2. **Trader's Treasure**: This name emphasizes the idea of saving and accumulating wealth.
# 3. **Accra Amanfu**: "Amanfu" is a Ghanaian word for "savings" or "treasury", so this name incorporates local language
# Response 5:
# Here are a few suggestions for a savings product for market traders in Accra:
#
# 1. **Makola Save**: "Makola" is a well-known market in Accra, so this name could resonate with market traders.
# 2. **Trader's Treasure**: This name emphasizes the idea of saving and accumulating wealth.
# 3. **Accra Amanfu**: "Amanfu" is a Ghanaian word for "savings" or "treasury", so this name incorporates local language
# ====TEMPERATURE 1.2====
# Response 1:
# Here are some name suggestions for a savings product tailored to market traders in Accra:
#
# 1. **MakolaSave**: "Makola" is a well-known market in Accra, and "Save" conveys the savings aspect of the product.
# 2. **TradeVault**: This name emphasizes the idea of a secure and trustworthy place to store savings, specifically designed for traders.
# 3. **AccraTrade Savings**: This name clearly indicates that the product is designed for traders in Accra
# Response 2:
# Here are a few name suggestions for a savings product for market traders in Accra:
#
# 1. **Makola Saver**: "Makola" is a well-known market in Accra, so this name could resonate with market traders.
# 2. **Trado Save**: "Trado" is a play on the word "trade," which is relevant to market traders, and "save" conveys the purpose of the product.
# 3. **Sika Su**: "Sika" means
# Response 3:
# Here are a few suggestions for a savings product name for market traders in Accra:
#
# 1. **Makola Savings**: "Makola" is a well-known market in Accra, and this name could resonate with market traders.
# 2. **Trader's Treasure**: This name plays on the idea of saving being a valuable treasure for market traders.
# 3. **Susupon** (pronounced "soo-soh-pohn"): This is a Ghanaian word that means "add to"
# Response 4:
# Here are some name suggestions for a savings product targeting market traders in Accra:
#
# 1. **Makola Save**: "Makola" is a well-known market in Accra, so this name immediately resonates with market traders.
# 2. **Trader's Treasure**: This name emphasizes the idea of saving and securing one's finances, like treasure.
# 3. **Suatu Savings**: "Suatu" is a Ga word meaning "ours" or "our own", which could appeal to the
# Response 5:
# Here are some suggestions for a savings product name targeting market traders in Accra:
#
# 1. **Makola Savings**: "Makola" is a well-known market in Accra, so this name immediately resonates with the target audience.
# 2. **Traders' Treasure**: This name conveys the idea of saving and accumulating wealth, which is attractive to market traders.
# 3. **Sika SOS**: "Sika" means "money" in the local Akan language, and "

# %% [markdown]
# **Temperature**
# 1. At temperature 0.0, the responses were generally more consistent and similar to one another. At temperature 1.2, the responses showed greater variation and creativity. For a loan decision-support system, a low temperature such as 0.0-0.3 would be more appropriate because the system should produce consistent and predictable responses rather than highly random recommendations. The final loan decision should also be based on defined financial criteria rather than creativity.

# %%
#part 2
LETTERS = {
"L001": """Dear Sir/Madam,
My name is Akosua Mensah and I have been selling provisions at Makola Market for 12 years.
I am applying for a loan of GHS 8,000 to buy a deep freezer and expand into frozen foods.
My current stall makes about GHS 900 profit each month. I have saved GHS 2,500 with your
susu scheme over the past two years and I have never missed a contribution. I can repay
GHS 450 monthly over 20 months. My sister, a teacher, will stand as my guarantor.
Thank you for considering my application.""",

"L002": """Hello,
I am Kwame Boateng, a commercial driver in Kumasi. I need GHS 25,000 urgently to repair my
trotro engine and settle some personal debts. Business has been slow but it will surely
pick up after the festive season. I can pay back whenever the money comes. I do not have
collateral at the moment but God willing everything will be fine. Please help me quickly.""",

"L003": """Dear Loan Committee,
I am Efua Darko, owner of Darko Fashions, a registered dressmaking business in Takoradi
(registration no. BN-2019-4482). I employ three apprentices. I request GHS 15,000 to
purchase two industrial sewing machines and fabric stock ahead of the Christmas season.
Last year my December revenue alone was GHS 22,000; monthly profit averages GHS 2,800.
I hold a fixed deposit of GHS 5,000 with GCB which I can pledge. Proposed repayment:
GHS 1,100 monthly for 15 months. Attached are my sales records for the past 18 months.""",

"L004": """Good day,
My name is Yaw Owusu. I want a loan for my poultry farm at Nsawam. The amount is GHS 12,000
for feed and 500 new layers. I started the farm last year. Sometimes I make good money,
around GHS 1,500 in a good month, but bird flu affected us in March and I lost many birds.
I am rebuilding now. I can repay in 18 months. My uncle has agreed to guarantee the loan
with his taxi.""",

"L005": """Dear Manager,
I am writing on behalf of the Adenta Women's Weaving Cooperative (14 members). We seek
GHS 30,000 to buy a bulk order of yarn directly from the factory, cutting out middlemen and
raising our margins from 15% to about 35%. The cooperative has operated for 6 years and
holds GHS 9,000 in our group account. We propose repayment of GHS 2,000 monthly over
16 months, backed by our group savings and joint liability agreement.""",

"L006": """Hi,
This is Kofi. I saw your advert. I want GHS 50,000 to start a car washing business, a
provision shop, and also import phones from Dubai. I am 22 and full of energy. I have not
started any of these yet but my friends say I am very business minded. I will pay back in
one year when the businesses are booming. No collateral but I am trustworthy.""",
}

GOLD = {
  "L001": {"applicant_name": "Akosua Mensah", "amount_ghs": 8000,  "purpose": "buy deep freezer / expand into frozen foods",
           "monthly_profit_ghs": 900,  "has_collateral_or_guarantor": True,  "repayment_months": 20},
  "L003": {"applicant_name": "Efua Darko",    "amount_ghs": 15000, "purpose": "industrial sewing machines and fabric stock",
           "monthly_profit_ghs": 2800, "has_collateral_or_guarantor": True,  "repayment_months": 15},
  "L006": {"applicant_name": "Kofi",          "amount_ghs": 50000, "purpose": "car wash, provision shop, phone imports",
           "monthly_profit_ghs": None, "has_collateral_or_guarantor": False, "repayment_months": 12},
}

print(f"{len(LETTERS)} letters loaded.")
# Out:
# 6 letters loaded.
